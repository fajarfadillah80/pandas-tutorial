# %% [markdown]
# ## membaca file
# pada library pandas terdapat modul yang dapat digunakan untuk membaca data tabular dengan format csv, excel, txt, dan lain sebagainya. pembacaan data dapat dilakukan dari data yang tersimpan di directory lokal, google drive, maupun website.

# %%
import pandas as pd

# %%
#melakukan import data yang berada di local directory
import os
os.getcwd() #melihat directory saat ini
os.chdir("D:\PELATIHAN\BOOTCAMP\SANBERCODE\DATA SET") #merubah posisi directory
 #melihat isi pada directory
# !dir 
df = pd.read_excel("SampleData.xlsx",sheet_name="SalesOrders") #membaca data excel
df
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is 049D-CA0F
#
#  Directory of D:\PELATIHAN\BOOTCAMP\SANBERCODE\DATA SET
#
# 14/09/2020  21:33    <DIR>          .
# 14/09/2020  21:33    <DIR>          ..
# 27/07/2020  13:34         4.005.705 2547_5839_bundle_archive.zip
# 07/08/2020  11:29           105.734 austin_weather.csv
# 27/07/2020  20:17    <DIR>          diamond
# 30/07/2020  20:57         3.192.560 diamonds-3.csv
# 07/08/2020  19:44         2.502.422 diamonds.csv
# 09/08/2020  13:59            42.618 Fat_Supply_Quantity_Data.csv
# 09/08/2020  13:59            44.619 Food_Supply_Quantity_kg_Data.csv
# 27/07/2020  20:17    <DIR>          footbal player
# 09/08/2020  13:59            43.687 Protein_Supply_Quantity_Data.csv
# 02/04/2020  19:23            66.037 SampleData.xlsx
# 09/08/2020  13:59             3.669 Supply_Food_Data_Descriptions.csv
# 14/08/2020  10:32            61.194 titanic.csv
# 14/09/2020  21:28            61.194 titanic.xlsx
# ...

# %%
#melakukan import data dari website
pd.read_csv("https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/shopping_data.csv") #masukkan link website pada argumen
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.head()   #menampilkan 5 data pertama
df.tail()   #menampilkan 5 data terakhir
